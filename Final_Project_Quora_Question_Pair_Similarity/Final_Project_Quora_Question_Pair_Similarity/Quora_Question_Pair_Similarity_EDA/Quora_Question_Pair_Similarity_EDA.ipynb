# %% [markdown]
# <h1 style="color:red; line-height:3; text-align:center; font-family:Arial Black">* Table of contents *</h1>

# %% [markdown]
# <h2 style="color:green; line-height:3; text-align:center; font-family:Arial Black">
#
# - Project Details<br>
# - Problem Statement<br>
# - Business Objectives and Constraints<br>
# - Tasks to Perform<br>
# - Type of Machine Learning Problem<br>
# - Source of the data<br>
# - Data Overview<br>
# - Implementation<br></h2>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Project Details *</h1>

# %% [markdown]
# <h3><div style="background:black; line-height:2">
#     <b style="color:blue; font-family:Arial Black">Project Title &emsp;:&ensp; </b><b style="color:green">Quora Question Pair Similarity</b><br>
#     <b style="color:blue; font-family:Arial Black">Technologies &ensp;:&ensp; </b><b style="color:green">ML, NLP, MLOPs, Streamlit</b><br>
#     <b style="color:blue; font-family:Arial Black">Domain &emsp;&emsp;&emsp;&nbsp;&nbsp;:&ensp; </b><b style="color:green">Social Networking</b><br>
#     <b style="color:blue; font-family:Arial Black">Team Name &emsp;&nbsp;:&ensp; </b><b style="color:green">Team Data Dynamos</b><br>
#     <b style="color:blue; font-family:Arial Black">Participants &emsp;:&ensp; </b><b style="color:green">1. Rini Varghese &ensp; 2. Shweta Kulkarni &ensp; 3. Suraj Honkamble <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 4. Uma Naga Silpa Bhupathiraju &ensp; 5. Utkarsha A Narkhede</b>
# </div></h3>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Problem Statement *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Over 100 million people visit Quora every month, so it's no surprise that many people ask similarly worded questions. Multiple questions with the same intent can cause seekers to spend more time finding the best answer to their question, and make writers feel they need to answer multiple versions of the same question. Quora values canonical questions because they provide a better experience to active seekers and writers, and offer more value to both of these groups in the long term. The main aim of the project is to predict whether a pair of questions are similar or not. </h3>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Business Objectives and Constraints *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">1. The cost of a Mis-Classification can be very high.<br>
# 2. We need probability of a pair of questions to be duplicates so that we can choose any threshold of choice.<br>
# 3. No strict latency concerns.<br>
# 4. Interpretability is partially important.</h3>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Tasks to Perform *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2;">1. Import the General libraries, NLP module, and Machine learning modules.<br>
#                         2. Load the dataset.<br>
#                         3. Text Preprocessing:<br>
#                         &ensp;&ensp;&ensp; i.   Removing html tags <br>
#                         &ensp;&ensp;&ensp; ii.  Removing Punctuations <br>
#                         &ensp;&ensp;&ensp; iii. Performing stemming <br>
#                         &ensp;&ensp;&ensp; iv.  Removing Stop words <br>
#                         &ensp;&ensp;&ensp; v.   Expanding contractions. <br>
#                         4. Apply Tokenization. <br>
#                         5. Apply Stemming. <br>
#                         6. Apply POS Tagging. <br>
#                         7. Apply Lemmatization. <br>
#                         8. Apply label encoding. <br>
#                         9. Feature Extraction. <br>
#                         10 Text to Numerical vector conversion:<br>
#                         &ensp;&ensp;&ensp; i.   Apply BOW(Count-Vectorizer). <br>
#                         &ensp;&ensp;&ensp; ii.  Apply TFIDF vectorizer. <br>
#                         &ensp;&ensp;&ensp; iii. Apply Word2Vector vectorizer. <br>
#                         &ensp;&ensp;&ensp; iv.  Apply Glove. <br>
#                         11. Data preprocessing. <br>
#                         12. Model Building. <br>
#                         13. Evaluate the model:<br>
#                         &ensp;&ensp;&ensp; i.   Confusion Matrix. <br>
#                         &ensp;&ensp;&ensp; ii.  Classification report. <br>
#                         14. Track your experiments with the help of MLFlow. <br>
#                         15. Break your code into production ready script. <br>
#                         16. Automation using Workflow Orchestration using Prefect.

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Type of Machine Learning Problem *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">It is a binary classification problem, for a given pair of questions we need to predict if they are duplicate or not.</h3>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Source of the data *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">
# https://github.com/Koorimikiran369/Quora-Question-Pairing/blob/main/train.csv.zip</h3>

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Data Overview *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">
#
# - Available Columns: `id`, `qid1`, `question1`, `question2`, `is_duplicate`
# - Class labels: `0`, `1`
# - Total training data / No. of rows: `404290`
# - No. of columns: `5`
# - Independent variables: `id`, `qid1`, `question1`, `question2`
# - Dependent variable: `is_duplicate`
# - No. of non-duplicate data points: `255027`(`63.08%`)
# - No. of duplicate data points: `149263`(`36.92 %`)

# %% [markdown]
# <h1 style="color:green; line-height:3; text-align:center; font-family:Arial Black">* Implementation *</h1>

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Import the required libraries</h2>

# %%
pip install distance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import distance
from fuzzywuzzy import fuzz
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
import warnings
warnings.filterwarnings('ignore')

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
# ...

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Load the dataset</h2>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile

# %%
with ZipFile('drive/MyDrive/data_quora.zip', 'r') as zipObj:
  zipObj.extractall('drive/MyDrive/quora_proj')

# %%
df = pd.read_csv('/content/drive/MyDrive/quora_proj/data_quora/train.csv')
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Basic Exploratory Data Analysis</h2>

# %%
print("Shape of dataset:{}\nNumber of Columns:{}\nNumber of Rows:{}".format(df.shape,df.shape[1],df.shape[0]))
# Out:
# Shape of dataset:(404290, 6)
# Number of Columns:6
# Number of Rows:404290

# %%
print("Total Number of Columns:{}\nColumns are:{}".format(len(df.columns), df.columns))
# Out:
# Total Number of Columns:6
# Columns are:Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate'], dtype='object')

# %%
df.dtypes
# Out:
# id               int64
# qid1             int64
# qid2             int64
# question1       object
# question2       object
# is_duplicate     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
df.isna().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %% [markdown]
# **<code style="color:green">There is 1 Missing value in `Question1` and 2 Missing values in `Question2`. Lets check these row and decide whether to drop these rows or fill with some suitable value.</code>**

# %%
df[df['question1'].isna()]
# Out:
#             id    qid1    qid2 question1  \
# 363362  363362  493340  493341       NaN
#
#                                                 question2  is_duplicate
# 363362  My Chinese name is Haichao Yu. What English na...             0

# %%
df[df['question2'].isna()]
# Out:
#             id    qid1    qid2                         question1 question2  \
# 105780  105780  174363  174364    How can I develop android app?       NaN
# 201841  201841  303951  174364  How can I create an Android app?       NaN
#
#         is_duplicate
# 105780             0
# 201841             0

# %% [markdown]
# **<code style="color:green">We Cannot compute these missing rows with any suitable value, hence it is better to drop these rows.</code>**

# %%
df = df.dropna()
df.isna().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **<code style="color:green">No Duplicate rows in Dataset</code>**

# %%
plt.figure(figsize=(8,6))
count = df['is_duplicate'].value_counts()
sns.barplot(x=count.index,y=count.values)
plt.title('Distribution of target variable')
plt.xlabel('duplicate')
plt.ylabel('count')
plt.show()

# %% [markdown]
# **<code style="color:green">The above plot shows the distribution of data points among output classes.</code>**

# %%
df['is_duplicate'].value_counts()
# Out:
# 0    255024
# 1    149263
# Name: is_duplicate, dtype: int64

# %%
print("Similar Question pairs: {} % ".format(round(df['is_duplicate'].mean()*100, 2)))
print("Different Question pairs: {} % ".format(100 - round(df['is_duplicate'].mean()*100, 2)))
# Out:
# Similar Question pairs: 36.92 %
# Different Question pairs: 63.08 %

# %% [markdown]
# **<code style="color:green">Thus our dataset is slightly imbalanced.</code>**

# %%
qids = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
unique_qs = len(np.unique(qids))
repeated_qs = np.sum(qids.value_counts() > 1)
print("Total no. unique questions: ", unique_qs)
print("Total no. of repeated questions: ", repeated_qs)
print('Maximum number of times a single question is repeated: {}\n'.format(max(qids.value_counts())))
# Out:
# Total no. unique questions:  537929
# Total no. of repeated questions:  111778
# Maximum number of times a single question is repeated: 157

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = ['unique questions','repeated questions'],y = [unique_qs,repeated_qs])
plt.title('Distribution of unique and repeated questions')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.hist(qids.value_counts(), bins=160)
plt.yscale('log')
plt.title('Log-Histogram of question appearance counts')
plt.xlabel('Number of occurences of each question')
plt.ylabel('Number of questions')
plt.show()

# %%
# Just convert df into lower case for better analysis
df['question1'] = df['question1'].str.lower()
df['question2'] = df['question2'].str.lower()

# %%
doc_corpus = list(set(list(df['question1']) + list(df['question2'])))
math_ques = [ques  for ques in doc_corpus if '[math]' in ques]
print("Percentage of math based questions:  {0:.3f} %".format(100*len(math_ques)/len(doc_corpus)))
print("Percentage of questions with multiple parts: {0:.3f} %".format(100*len([ques for ques in doc_corpus if len(ques.split('?'))>=2 ])/len(doc_corpus) ))
print("Percentage of personal or opinion-based questions: {0:.3f} %".format(100*len([ques for ques in doc_corpus if ('you' in ques) or ('i' in ques) or ('we' in ques) or ('they' in ques) or ('he' in ques) or ('she' in ques) or ('it' in ques) or ('me' in ques) or ('him' in ques) or ('her' in ques) or ('us' in ques) or ('them' in ques) or ('who' in ques) or ('whom' in ques) or ('them' in ques)])/len(doc_corpus)))
# Out:
# Percentage of math based questions:  0.139 %
# Percentage of questions with multiple parts: 99.865 %
# Percentage of personal or opinion-based questions: 98.979 %

# %%
# Let's remove the id column since it is not important
df = df.drop(['id'], axis=1)

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Basic Feature Extraction</h2>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Let us construct a few features:
#
# - q1_len = Length of q1
# - q2_len = Length of q2
# - q1_n_words = Number of words in Question 1
# - q2_n_words = Number of words in Question 2
# - word_common = (Number of common unique words in Question 1 and Question 2)
# - word_total =(Total num of words in Question 1 + Total num of words in Question 2)
# - word_share = (word_common)/(word_total)</h3>

# %%
df['q1_len'] = df['question1'].str.len()
df['q2_len'] = df['question2'].str.len()
df['q1_n_words'] = df['question1'].apply(lambda row: len(row.split(" ")))
df['q2_n_words'] = df['question2'].apply(lambda row: len(row.split(" ")))

def common_wrd(row):
        x = set(row['question1'].lower().strip().split(" ")) 
        y = set(row['question2'].lower().strip().split(" "))
        return 1.0 * len(x & y)


def total(row):
        set1 = set(row['question1'].lower().strip().split(" "))
        set2 = set(row['question2'].lower().strip().split(" "))
        return 1.0 * (len(set1) + len(set2))

def word_share(row):
        x = row['word_common']/row['word_total']
        return  x
    
df['word_common'] = df.apply(common_wrd,axis=1)
df['word_total'] = df.apply(total,axis=1)
df['word_share'] = df.apply(word_share,axis=1)


df.head()
# Out:
#    qid1  qid2                                          question1  \
# 0     1     2  what is the step by step guide to invest in sh...
# 1     3     4  what is the story of kohinoor (koh-i-noor) dia...
# 2     5     6  how can i increase the speed of my internet co...
# 3     7     8  why am i mentally very lonely? how can i solve...
# 4     9    10  which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      66
# 1  what would happen if the indian government sto...             0      51
# 2  how can internet speed be increased by hacking...             0      73
# 3  find the remainder when [math]23^{24}[/math] i...             0      50
# 4            which fish would survive in salt water?             0      76
#
#    q2_len  q1_n_words  q2_n_words  word_common  word_total  word_share
# ...

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Analysis using extracted features</h2>

# %% [markdown]
# <h4 style="color:gray; line-height:1.2">Analysis of question character length feature</h4>

# %%
print('Minimum no. of characters in question1 : ' , df['q1_len'].min())
print('Minimum no.of characters in question2 : ' , df['q2_len'].min())

print('Average no. of characters in question1 : ' , int(df['q1_len'].mean()))
print('Average no. of characters in question2 : ' , int(df['q2_len'].mean()))

print('Maximum no. of characters in question1 : ' , df['q1_len'].max())
print('Maximum no. of characters in question2 : ' , df['q2_len'].max())

print("Number of Questions with minimum characters [question1] :", df[df['q1_len']== df['q1_len'].min()].shape[0])
print("Number of Questions with minimum characters [question2] :", df[df['q2_len']== df['q2_len'].min()].shape[0])

print("Number of Questions with maximum characters [question1] :", df[df['q1_len']== df['q1_len'].max()].shape[0])
print("Number of Questions with minimum characters [question2] :", df[df['q2_len']== df['q2_len'].max()].shape[0])
# Out:
# Minimum no. of characters in question1 :  1
# Minimum no.of characters in question2 :  1
# Average no. of characters in question1 :  59
# Average no. of characters in question2 :  60
# Maximum no. of characters in question1 :  623
# Maximum no. of characters in question2 :  1169
# Number of Questions with minimum characters [question1] : 19
# Number of Questions with minimum characters [question2] : 2
# Number of Questions with maximum characters [question1] : 1
# Number of Questions with minimum characters [question2] : 3

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
sns.distplot(df[df['is_duplicate'] == 0]['q1_len'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['q1_len'], label='Duplicate', color='blue')
plt.legend();

plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 0]['q2_len'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['q2_len'], label='Duplicate', color='blue')
plt.legend();

plt.suptitle("Question length for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# <h4 style="color:gray; line-height:1.2">Analysis of question word length feature</h4>

# %%
print('Minimum no. of words in question1 : ' , df['q1_n_words'].min())
print('Minimum no.of words in question2 : ' , df['q2_n_words'].min())

print('Average no. of words in question1 : ' , int(df['q1_n_words'].mean()))
print('Average no. of words in question2 : ' , int(df['q2_n_words'].mean()))

print('Maximum no. of words in question1 : ' , df['q1_n_words'].max())
print('Maximum no. of words in question2 : ' , df['q2_n_words'].max())

print("Number of Questions with minimum words [question1] :", df[df['q1_n_words']== df['q1_n_words'].min()].shape[0])
print("Number of Questions with minimum words [question2] :", df[df['q2_n_words']== df['q2_n_words'].min()].shape[0])

print("Number of Questions with maximum words [question1] :", df[df['q1_n_words']== df['q1_n_words'].max()].shape[0])
print("Number of Questions with minimum words [question2] :", df[df['q2_n_words']== df['q2_n_words'].max()].shape[0])
# Out:
# Minimum no. of words in question1 :  1
# Minimum no.of words in question2 :  1
# Average no. of words in question1 :  10
# Average no. of words in question2 :  11
# Maximum no. of words in question1 :  125
# Maximum no. of words in question2 :  237
# Number of Questions with minimum words [question1] : 66
# Number of Questions with minimum words [question2] : 22
# Number of Questions with maximum words [question1] : 1
# Number of Questions with minimum words [question2] : 13

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
sns.distplot(df[df['is_duplicate'] == 0]['q1_n_words'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['q1_n_words'], label='Duplicate', color='blue')
plt.legend();

plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 0]['q2_n_words'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['q2_n_words'], label='Duplicate', color='blue')
plt.legend();

plt.suptitle("Word Counts for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# <h4 style="color:gray; line-height:1.2">Analysis of word share feature</h4>

# %%
print('Minimum word share : ' , df['word_share'].min())

print('Average word share : ' , int(df['word_share'].mean()))

print('Maximum word share : ' , df['word_share'].max())

print("Number of Questions with minimum word share :", df[df['word_share']== df['word_share'].min()].shape[0])

print("Number of Questions with maximum word share :", df[df['word_share']== df['word_share'].max()].shape[0])
# Out:
# Minimum word share :  0.0
# Average word share :  0
# Maximum word share :  0.5
# Number of Questions with minimum word share : 22366
# Number of Questions with maximum word share : 562

# %%
plt.figure(figsize=(18,5))
sns.distplot(df[df['is_duplicate'] == 0]['word_share'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['word_share'], label='Duplicate', color='blue')
plt.legend();
plt.suptitle(" Word Sharing for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# <h4 style="color:gray; line-height:1.2">Analysis of word common feature</h4>

# %%
print('Minimum no. of common words : ' , df['word_common'].min())

print('Average no. of common words : ' , int(df['word_common'].mean()))

print('Maximum no. of common words : ' , df['word_common'].max())

print("Number of Questions with minimum common words :", df[df['word_common']== df['word_common'].min()].shape[0])

print("Number of Questions with maximum common words :", df[df['word_common']== df['word_common'].max()].shape[0])
# Out:
# Minimum no. of common words :  0.0
# Average no. of common words :  4
# Maximum no. of common words :  41.0
# Number of Questions with minimum common words : 22366
# Number of Questions with maximum common words : 1

# %%
plt.figure(figsize=(18,5))
sns.distplot(df[df['is_duplicate'] == 0]['word_common'], label='Non-Duplicate', color='red')
sns.distplot(df[df['is_duplicate'] == 1]['word_common'], label='Duplicate', color='blue')
plt.legend();
plt.suptitle("Total Common Word Counts for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Basic Text Preprocessing</h2>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">
#
# - Converting to lower case
# - Removing HTML Tags
# -Expanding Contractions
# -Removing Punctuations
# -Removing Stopwords
# -Performing Stemming</h3>

# %%
# Removing accents from question1
df['question1'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
# Out:
# 0         what is the step by step guide to invest in sh...
# 1         what is the story of kohinoor (koh-i-noor) dia...
# 2         how can i increase the speed of my internet co...
# 3         why am i mentally very lonely? how can i solve...
# 4         which one dissolve in water quikly sugar, salt...
#                                 ...
# 404285    how many keywords are there in the racket prog...
# 404286            do you believe there is life after death?
# 404287                                    what is one coin?
# 404288    what is the approx annual cost of living while...
# 404289                what is like to have sex with cousin?
# Name: question1, Length: 404287, dtype: object

# %%
# Removing accents from question2
df['question2'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
# Out:
# 0         what is the step by step guide to invest in sh...
# 1         what would happen if the indian government sto...
# 2         how can internet speed be increased by hacking...
# 3         find the remainder when [math]23^{24}[/math] i...
# 4                   which fish would survive in salt water?
#                                 ...
# 404285    how many keywords are there in perl programmin...
# 404286           is it true that there is life after death?
# 404287                                    what's this coin?
# 404288    i am having little hairfall problem but i want...
# 404289        what is it like to have sex with your cousin?
# Name: question2, Length: 404287, dtype: object

# %%
def preprocess(q):
    
    q = q.replace("s'", "")
    
    # Removing leading and trailing spaces
    q = re.sub(r"^\s+|\s+$", "", q)
    
    # Substituting multiple whitespaces with single whitespace
    q = re.sub(r"\s+", " ", q)
    
    q = q.replace('[math]', '')
    
    q = re.sub("<.*?>", "", q)
    
    q = q.replace(',000,000,000 ', 'b ')
    q = q.replace(',000,000 ', 'm ')
    q = q.replace(',000 ', 'k ')
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)
    
    
    contractions = {
        "’" : "'",
        "won't" : "will not",
        "can't" : "cannot",
        "what's" : "what is",
        "it's" : "it is",
        "i'm" : "i am",
        "'s" : "own",
        "he's" : "he is",
        "she's" : "she is",
        "i'd" : "had",
        "%+" : "percent and more",
        "+%" : "percent and more",
        "%" : "percent",
        "%d" : "%d",
        "@" : "at",
        "$" : " dollar "
    }
    
    q_decontracted = []

    for word in q.split():
        if word in contractions:
            word = contractions[word]

        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ll", " will")
    
    # Removing HTML tags
    q = BeautifulSoup(q)
    q = q.get_text()
    
    # Remove punctuations
    pattern = re.compile('\W')
    q = re.sub(pattern, ' ', q).strip()

    # Removing links and hashtags
    pattern=re.compile('https?\S+|www.\S+|#[a-zA-Z0-9]+')
    q = re.sub(pattern,'',q)
                                                                                       
    
    # Removing stop words
    stop_words=set(stopwords.words('english'))      
    q = ' '.join([word for word in q.split() if word not in stop_words])
                                                                                       
    # Performing stemming
    stemmer=SnowballStemmer('english')
    q = ' '.join([stemmer.stem(word) for word in q.split()])
    
    
    return q

# %%
df['question1'] = df['question1'].apply(preprocess)
df['question2'] = df['question2'].apply(preprocess)

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Advance Feature Extraction</h2>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Let us construct a few more features:
#
# - cwc_min : Ratio of common_word_count to min length of word count of q1 and q2<br>
# cwc_min = common_word_count / (min(len(q1_words), len(q2_words))
# - cwc_max : Ratio of common_word_count to max length of word count of q1 and q2<br>
# cwc_max = common_word_count / (max(len(q1_words), len(q2_words))
# - csc_min : Ratio of common_stop_count to min length of stop count of q1 and q2<br>
# csc_min = common_stop_count / (min(len(q1_stops), len(q2_stops))
# - csc_max : Ratio of common_stop_count to max length of stop count of q1 and q2<br>
# csc_max = common_stop_count / (max(len(q1_stops), len(q2_stops))
# - ctc_min : Ratio of common_token_count to min length of token count of q1 and q2<br>
# ctc_min = common_token_count / (min(len(q1_tokens), len(q2_tokens))
# - ctc_max : Ratio of common_token_count to max length of token count of q1 and q2<br>
# ctc_max = common_token_count / (max(len(q1_tokens), len(q2_tokens))
# - last_word_eq : Check if First word of both questions is equal or not<br>
# last_word_eq = int(q1_tokens[-1] == q2_tokens[-1])
# - first_word_eq : Check if First word of both questions is equal or not<br>
# first_word_eq = int(q1_tokens[0] == q2_tokens[0])
# - abs_len_diff : Abs. length difference<br>
# abs_len_diff = abs(len(q1_tokens) - len(q2_tokens))
# - mean_len : Average Token Length of both Questions<br>
# mean_len = (len(q1_tokens) + len(q2_tokens))/2
# - longest_substr_ratio : Ratio of length longest common substring to min lenghth of token count of q1 and q2<br>
# longest_substr_ratio = len(longest common substring) / min(len(q1_tokens), len(q2_tokens))</h3>

# %%
def get_token_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    SAFE_DIV = 0.0001
    
    stop_words=set(stopwords.words('english'))
    
    token_features = [0.0]*8
    
    # Converting sentence into tokens
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features
    
    # Get the non-stopwords in question pair
    q1_words = set([word for word in q1_tokens if word not in stop_words])
    q2_words = set([word for word in q2_tokens if word not in stop_words])
    
    # Get the stopwords in question pair
    q1_stops = set([word for word in q1_tokens if word in stop_words])
    q2_stops = set([word for word in q2_tokens if word in stop_words])
    
    # Get the common non-stopwords in question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords in question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common tokens in question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))
    
    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features

# %%
token_features = df.apply(get_token_features, axis=1)

# %%
df["cwc_min"]       = list(map(lambda x: x[0], token_features))
df["cwc_max"]       = list(map(lambda x: x[1], token_features))
df["csc_min"]       = list(map(lambda x: x[2], token_features))
df["csc_max"]       = list(map(lambda x: x[3], token_features))
df["ctc_min"]       = list(map(lambda x: x[4], token_features))
df["ctc_max"]       = list(map(lambda x: x[5], token_features))
df["last_word_eq"]  = list(map(lambda x: x[6], token_features))
df["first_word_eq"] = list(map(lambda x: x[7], token_features))

# %%
def get_length_features(row):
    q1=row['question1']
    q2=row['question2']
    length_features=[0.0]*3
    
    q1_tokens=q1.split()   #question1 token
    q2_tokens=q2.split()   #question2 token
    if len(q1_tokens)==0 or len(q2_tokens)==0:
        return length_features
    
    length_features[0]=abs(len(q1_tokens) - len(q2_tokens))            #absolute length
    length_features[1]=(len(q1_tokens) + len(q2_tokens))/2             #average token length
    
    return length_features

# %%
length_features=df.apply(get_length_features, axis=1)

df['abs_len_diff'] = list(map(lambda x: x[0], length_features))
df['mean_len'] = list(map(lambda x: x[1], length_features))

# %%
# Get the longest substring ratio
def get_longest_substr_ratio(a, b):
    strs = list(distance.lcsubstrings(a, b))
    if len(strs) == 0:
        return 0
    else:
        return len(strs[0]) / (min(len(a), len(b)) + 1)

# %%
df["longest_substr_ratio"]  = df.apply(lambda x: get_longest_substr_ratio(x["question1"], x["question2"]), axis=1)

# %%
df["longest_substr_ratio"] = list(df["longest_substr_ratio"])

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Let's construct fuzzy features
#
# - fuzz_ratio
# - fuzz_partial_ratio
# - token_sort_ratio
# - token_set_ratio</h3>

# %%
def get_fuzzy_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    fuzzy_features = [0.0]*4
    
    #fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)
    
    #fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)
    
    #token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)
    
    #token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)
    
    return fuzzy_features

# %%
fuzzy_features = df.apply(get_fuzzy_features, axis=1)

# %%
df['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
df['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
df['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
df['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %% [markdown]
# <h2 style="color:gray; line-height:1.2">Analysis using newly extracted features</h2>

# %%
token_features_df=df[['cwc_min', 'cwc_max', 'csc_min', 'csc_max', 'ctc_min',
       'ctc_max', 'last_word_eq', 'first_word_eq', 'abs_len_diff', 'mean_len', 'longest_substr_ratio', 'fuzz_ratio',
                      'fuzz_partial_ratio', 'token_sort_ratio', 'token_set_ratio']]

# %%
for col in token_features_df.columns:
    plt.figure(figsize=(18,5))
    sns.distplot(df[df['is_duplicate'] == 0][col], label='Non-Duplicate', color='red')
    sns.distplot(df[df['is_duplicate'] == 1][col], label='Duplicate', color='blue')
    plt.legend();
    plt.suptitle("Relationship between {} and is duplicate".format(col), color='blue', fontsize=18);

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Visualization using T-SNE with Dimensionality Reduction for 15 Features</h3>

# %%
X = MinMaxScaler().fit_transform(token_features_df)
y = df['is_duplicate'].values

# %%
tsne2d = TSNE(
    n_components=2,
    init='random', 
    random_state=101,
    method='barnes_hut',
    n_iter=500,
    verbose=2,
    angle=0.5).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 404287 samples in 1.305s...
# [t-SNE] Computed neighbors for 404287 samples in 604.376s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 404287
# [t-SNE] Computed conditional probabilities for sample 2000 / 404287
# [t-SNE] Computed conditional probabilities for sample 3000 / 404287
# [t-SNE] Computed conditional probabilities for sample 4000 / 404287
# [t-SNE] Computed conditional probabilities for sample 5000 / 404287
# [t-SNE] Computed conditional probabilities for sample 6000 / 404287
# [t-SNE] Computed conditional probabilities for sample 7000 / 404287
# [t-SNE] Computed conditional probabilities for sample 8000 / 404287
# [t-SNE] Computed conditional probabilities for sample 9000 / 404287
# [t-SNE] Computed conditional probabilities for sample 10000 / 404287
# [t-SNE] Computed conditional probabilities for sample 11000 / 404287
# [t-SNE] Computed conditional probabilities for sample 12000 / 404287
# ...

# %%
x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})

# draw the plot in appropriate place in the grid
sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, height=8, palette="Set1",markers=['s','o'])

plt.savefig("2dplot.png")

# %%
import csv

df.to_csv('cleaned.csv')
